# %%
# %cd music/
# Out:
# /Users/evelyn/Downloads/dl_signal_master/music

# %%
# !wget https://homes.cs.washington.edu/~thickstn/media/musicnet.npz
# Out:
# --2020-11-10 02:42:35--  https://homes.cs.washington.edu/~thickstn/media/musicnet.npz
# Resolving homes.cs.washington.edu (homes.cs.washington.edu)... 128.208.3.226, 2607:4000:200:12::e2
# Connecting to homes.cs.washington.edu (homes.cs.washington.edu)|128.208.3.226|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11721310906 (11G)
# Saving to: ‘musicnet.npz’
#
# musicnet.npz        100%[===================>]  10.92G  18.7MB/s    in 23m 40s
#
# 2020-11-10 03:06:15 (7.87 MB/s) - ‘musicnet.npz’ saved [11721310906/11721310906]

# %%
# !python -u resample.py musicnet.npz musicnet_11khz.npz 44100 11000

# %%
# !rm musicnet.npz

# %%
# !python -u parse_file.py

# %%
# !rm musicnet_11khz.npz
# %cd ..

# %%
python -u transformer/train_crnn.py

# %%
python -u transformer/train_trans.py
